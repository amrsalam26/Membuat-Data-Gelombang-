# %% [markdown]
# # **A. Membuat Data Dasar**

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# """
# 1. Membuat Data
# 2. Membuat Plot
# 3. Menampilkan Plot
#
# """

# %% [markdown]
# # 1. Membuat Data

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
y2 = np.array([1,16,81,256,625])

# %% [markdown]
# # 2. Membuat Plot dan Menampilkan Data

# %%
plt.plot(x,y)
plt.plot(x,y2)
plt.show()

# %% [markdown]
# # **B. Membuat Data Gelombang**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# """
# 1. Membuat Data
# 2. Membuat Plot
# 3. Menampilkan Plot
#
# """

# %% [markdown]
# # 1. Membuat Data (sin(2wt + theta))

# %%
def sinusGenerator(amplitudo,frekuensi,tAkhir,theta):
  t = np.arange(0,tAkhir,0.1)
  y = amplitudo * np.sin(2*frekuensi*t + np.deg2rad(theta))
  return t,y

# %% [markdown]
# #2. Membuat Plot

# %%
t1,y1 = sinusGenerator(1,1,4,0)
t2,y2 = sinusGenerator(1,1,4,30)
t3,y3 = sinusGenerator(1,1,4,60)
t4,y = sinusGenerator(1,1,4,90)

# %% [markdown]
# #3. Menampilkan Plot

# %%
plt.plot(t1,y1)
plt.plot(t2,y2, 'r')
plt.plot(t3,y3, 'y--')
plt.plot(t4,y4, 'c-o')
plt.show()

# %% [markdown]
# # **C. Membuat Data Grafik Sinusoidal**

# %% [markdown]
# 1. Membuat Data
# 2. Membuat Plot
# 3. Menampilkan Plot

# %% [markdown]
# #1. Membuat Data

# %%
def sinusGenerator(amplitudo,frekuensi,tAkhir,theta):
  t = np.arange(0,tAkhir,0.1)
  y = amplitudo * np.sin(2*frekuensi*t + np.deg2rad(theta))
  return t,y

# %%
amplitudo = 1
frekuensi = 1
theta = 0 
tAkhir = 4

# %%
t,y = sinusGenerator(amplitudo,frekuensi,tAkhir,theta)

# %% [markdown]
# #2. Membuat Plot

# %%
Judul = 'Grafik Sinusoidal\n'
rumus = r'$ \mathcal{Y} = A.sin(2 \omega t + \theta)$' + '\n'
Parameter1 = r'$ A= $' + str(amplitudo) + ' cm, '
Parameter2 = r'$ \omega = $' + str(frekuensi) + r'$ \mathit{Hz}$' +', ' 
Parameter3 = r'$ \theta = $' +str(theta) + r'$^{o} $'

# %% [markdown]
# # 3. Menampilkan Plot

# %%
plt.plot(t,y)
plt.title(Judul + rumus + Parameter1 + Parameter2 + Parameter3)
plt.xlabel('waktu(detik)')
plt.ylabel('magnitudo(cm)')
plt.show()
